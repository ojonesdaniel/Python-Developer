# %% [markdown]
# 1. Calcule o fatorial de um número.

# %%
num = int(imput("Digite um número:"))

# %% [markdown]
# 2. Gere os primeiros N números da sequência de Fibonacci.
# 3. Verifique se um número é primo.
# 4. Liste todos os números primos até N.
# 5. Calcule a soma dos dígitos de um número.
# 6. Inverta um número inteiro.
# 7. Verifique se um número é palíndromo.
# 8. Gere a tabuada de 1 a 10.
# 9. Calcule o MDC entre dois números.
# 10. Calcule o MMC entre dois números.
# 11. Conte quantos números pares e ímpares existem em um intervalo.
# 12. Simule um caixa eletrônico com saques até saldo zerar.
# 13. Calcule a média de notas até o usuário digitar -1.
# 14. Imprima um triângulo com *.
# 15. Imprima um losango com *.
# 16. Verifique se um número é perfeito.
# 17. Some todos os números divisíveis por 3 e 5 até N.
# 18. Gere uma matriz NxN e calcule a soma da diagonal principal.
# 19. Simule um jogo de adivinhação.
# 20. Ordene um vetor usando Bubble Sort.
