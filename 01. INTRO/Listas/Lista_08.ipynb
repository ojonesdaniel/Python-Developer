# %% [markdown]
# - Escreva um algoritmo que possua um vetor de 10 posições de npumeros inteiros.
# - O algoritmo deve solicitar que o usuário informe o valor de cadas posição.
# - Ao final realize a soma dos números pares e apresnte o resultado

# %%
valores = list()

while True:
    num = int(input("Digite um número para tirar a média e o valor -5 para encerrar a lista"))
    if num != -5:
        valores.append(num)
    else:
        break

# %% [markdown]
# 1. Soma dos Elmentos: Escreva um programa Java que receba um vetor de números inteiros e calcule a soma de todos os elementos do vetor.

# %%
soma = 0

while True:
    if num != -5:
        num = int(input("Digite um número:"))
        soma = num + soma
    else:
        break

print(f"Essa é a soma dos números: {soma}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 soma = 0
#       2
#       3 while True:
# ----> 4     if num != -5:
#       5         num = int(input("Digite um número:"))
#       6         soma = num + soma
#       7     else:
#
# NameError: name 'num' is not defined
