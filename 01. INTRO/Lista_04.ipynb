# %%
SalarioAtual = float(input("Digite seu salário atual:"))
percAumento = float(input("Digite o percentual do seu aumento:"))

SalarioNovo =  SalarioAtual + (SalarioAtual / 100 * 20)

print(f"O salário novo é ficará no valor de: R${SalarioNovo}.)
